# %%
# !pip install ultralytics opencv-python matplotlib numpy
# Out:
# Requirement already satisfied: ultralytics in c:\users\dinesh\anaconda3\lib\site-packages (8.4.6)
# Requirement already satisfied: opencv-python in c:\users\dinesh\anaconda3\lib\site-packages (4.13.0.90)
# Requirement already satisfied: matplotlib in c:\users\dinesh\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: numpy in c:\users\dinesh\anaconda3\lib\site-packages (2.1.3)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (1.15.3)
# Requirement already satisfied: torch>=1.8.0 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (2.9.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (0.24.1)
# Requirement already satisfied: psutil>=5.8.0 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (5.9.0)
# Requirement already satisfied: polars>=0.20.0 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (1.37.1)
# Requirement already satisfied: ultralytics-thop>=2.0.18 in c:\users\dinesh\anaconda3\lib\site-packages (from ultralytics) (2.0.18)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dinesh\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\dinesh\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dinesh\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dinesh\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\dinesh\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dinesh\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dinesh\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: polars-runtime-32==1.37.1 in c:\users\dinesh\anaconda3\lib\site-packages (from polars>=0.20.0->ultralytics) (1.37.1)
# Requirement already satisfied: six>=1.5 in c:\users\dinesh\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\dinesh\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dinesh\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dinesh\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dinesh\anaconda3\lib\site-packages (from requests>=2.23.0->ultralytics) (2025.11.12)
# Requirement already satisfied: filelock in c:\users\dinesh\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\dinesh\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\dinesh\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in c:\users\dinesh\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\dinesh\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in c:\users\dinesh\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (2025.3.2)
# Requirement already satisfied: setuptools in c:\users\dinesh\anaconda3\lib\site-packages (from torch>=1.8.0->ultralytics) (72.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\dinesh\anaconda3\lib\site-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dinesh\anaconda3\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
lane_images = [
    "Lane1.jpg",
    "Lane2.jpg",
    "Lane3.jpg",
    "Lane4.jpg"
]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

vehicle_classes = [2, 3, 5, 7]  # car, motorcycle, bus, truck

def count_vehicles(image_path):
    results = model(image_path, verbose=False)
    count = 0

    for r in results:
        for box in r.boxes:
            if int(box.cls) in vehicle_classes:
                count += 1

    return count

# %%
lane_counts = {}

for i, img in enumerate(lane_images, start=1):
    lane_counts[f"Lane {i}"] = count_vehicles(img)

print(lane_counts)
# Out:
# {'Lane 1': 29, 'Lane 2': 20, 'Lane 3': 26, 'Lane 4': 33}

# %%
MAX_GREEN = 60
MIN_GREEN = 10

max_count = max(lane_counts.values())

traffic_timings = {}

for lane, count in lane_counts.items():
    if max_count == 0:
        time = MIN_GREEN
    else:
        time = int((count / max_count) * MAX_GREEN)
        time = max(time, MIN_GREEN)

    traffic_timings[lane] = time

print(traffic_timings)
# Out:
# {'Lane 1': 52, 'Lane 2': 36, 'Lane 3': 47, 'Lane 4': 60}

# %%
green_order = sorted(
    traffic_timings.items(),
    key=lambda x: x[1],
    reverse=True
)

for lane, time in green_order:
    print(f"{lane} → GREEN for {time} seconds")
# Out:
# Lane 4 → GREEN for 60 seconds
# Lane 1 → GREEN for 52 seconds
# Lane 3 → GREEN for 47 seconds
# Lane 2 → GREEN for 36 seconds
